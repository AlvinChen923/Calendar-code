# %%
### New vehicles new version ###

import matplotlib.pyplot as plt
import pandas as pd

class SalesConsultant:
    def __init__(self, base_salary, commission_per_unit, commission_rate_1, commission_rate_2, commission_rate_3, commission_rate_4, commission_rate_5, sales_level_1, 
                 sales_level_2, sales_Achievement_1, sales_Achievement_2, NPS, velocity, Accessory_Achievement):
        self.base_salary = base_salary
        self.commission_per_unit = commission_per_unit
        self.commission_rate_1 = commission_rate_1
        self.commission_rate_2 = commission_rate_2
        self.commission_rate_3 = commission_rate_3
        self.commission_rate_4 = commission_rate_4
        self.commission_rate_5 = commission_rate_5
        self.sales_level_1 = sales_level_1
        self.sales_level_2 = sales_level_2
        self.sales_Achievement_1 = sales_Achievement_1
        self.sales_Achievement_2 = sales_Achievement_2
        self.NPS = NPS
        self.velocity = velocity
        self.Accessory_Achievement = Accessory_Achievement
        self.total_earnings = 0

    def calculate_commission(self, sales, vehicle_sales):
    
        if vehicle_sales >= self.sales_level_2 and self.NPS > 5 and self.velocity <= 12 and self.Accessory_Achievement >= sales_Achievement_2:
            self.total_earnings = self.base_salary * sales + (self.commission_per_unit + commission_rate_5 + commission_rate_4 + commission_rate_3 +commission_rate_1) * vehicle_sales 
        elif vehicle_sales >= self.sales_level_2 and self.NPS > 5 and self.velocity <= 12 and self.Accessory_Achievement >= sales_Achievement_1:
            self.total_earnings = self.base_salary * sales + (self.commission_per_unit + commission_rate_5 + commission_rate_4 + commission_rate_2 +commission_rate_1) * vehicle_sales
        elif vehicle_sales >= self.sales_level_2 and self.NPS > 5 and self.velocity <= 12:
            self.total_earnings = self.base_salary * sales + (self.commission_per_unit + commission_rate_5 + commission_rate_4 + commission_rate_1) * vehicle_sales
        elif vehicle_sales >= self.sales_level_2 and self.NPS > 5 and self.Accessory_Achievement >= sales_Achievement_2:
            self.total_earnings = self.base_salary * sales + (self.commission_per_unit + commission_rate_5 + commission_rate_1 + commission_rate_3) * vehicle_sales
        elif vehicle_sales >= self.sales_level_2 and self.NPS > 5 and self.Accessory_Achievement >= sales_Achievement_1:
            self.total_earnings = self.base_salary * sales + (self.commission_per_unit + commission_rate_5 + commission_rate_1 + commission_rate_2) * vehicle_sales
        elif vehicle_sales >= self.sales_level_2:
            self.total_earnings = self.base_salary * sales + (self.commission_per_unit + commission_rate_5) * vehicle_sales
        
        elif vehicle_sales >= self.sales_level_1 and self.NPS > 5 and self.velocity <= 12 and self.Accessory_Achievement >= sales_Achievement_2:
            self.total_earnings = self.base_salary * sales + (self.commission_per_unit + commission_rate_4 + commission_rate_3 +commission_rate_1) * vehicle_sales 
        elif vehicle_sales >= self.sales_level_1 and self.NPS > 5 and self.velocity <= 12 and self.Accessory_Achievement >= sales_Achievement_1:
            self.total_earnings = self.base_salary * sales + (self.commission_per_unit + commission_rate_4 + commission_rate_2 +commission_rate_1) * vehicle_sales
        elif vehicle_sales >= self.sales_level_1 and self.NPS > 5 and self.velocity <= 12:
            self.total_earnings = self.base_salary * sales + (self.commission_per_unit + commission_rate_4 + commission_rate_1) * vehicle_sales
        elif vehicle_sales >= self.sales_level_1 and self.NPS > 5 and self.Accessory_Achievement >= sales_Achievement_2:
            self.total_earnings = self.base_salary * sales + (self.commission_per_unit + commission_rate_1 + commission_rate_3) * vehicle_sales
        elif vehicle_sales >= self.sales_level_1 and self.NPS > 5 and self.Accessory_Achievement >= sales_Achievement_1:
            self.total_earnings = self.base_salary * sales + (self.commission_per_unit + commission_rate_1 + commission_rate_2) * vehicle_sales
        elif vehicle_sales >= self.sales_level_1:
            self.total_earnings = self.base_salary * sales + self.commission_per_unit * vehicle_sales
        
        else:
            self.total_earnings = self.base_salary * sales

    def calculate_total_earnings(self):
        return self.total_earnings

base_salary = 60000/12
commission_per_unit = 250
commission_rate_1 = 50  
commission_rate_2 = 50 
commission_rate_3 = 75
commission_rate_4 = 50
commission_rate_5 = 50
sales_level_1 = 8  
sales_level_2 = 18
sales_Achievement_1 = 1.0  # Assigning 100% as a float value (1.0 represents 100%)
sales_Achievement_2 = 1.2   
sales = 1
NPS = 6
velocity = 10
Accessory_Achievement = 0.9


consultant1 = SalesConsultant(base_salary, commission_per_unit, commission_rate_1, commission_rate_2, commission_rate_3, commission_rate_4, commission_rate_5, sales_level_1, 
                 sales_level_2, sales_Achievement_1, sales_Achievement_2, NPS, velocity, Accessory_Achievement)

vehicle_sales_range = range(1, 41)

earnings1 = []
for vehicle_sales in vehicle_sales_range:
    consultant1.calculate_commission(sales, vehicle_sales)
    total_earnings = consultant1.calculate_total_earnings()
    earnings1.append(total_earnings)

plt.figure(figsize=(10, 5))
plt.plot(vehicle_sales_range, earnings1, label='Total Earnings')
plt.xlabel('Vehicle Sales')
plt.ylabel('Total Earnings')
plt.title('Sales Consultant Earnings vs Vehicle Sales')
plt.grid(True)
plt.legend()
plt.show()

data = {'Vehicle Sales': list(vehicle_sales_range), 'Total Earnings': earnings1}
df = pd.DataFrame(data)
print(df)
# Out:
#     Vehicle Sales  Total Earnings
# 0               1          5000.0
# 1               2          5000.0
# 2               3          5000.0
# 3               4          5000.0
# 4               5          5000.0
# 5               6          5000.0
# 6               7          5000.0
# 7               8          7800.0
# 8               9          8150.0
# 9              10          8500.0
# 10             11          8850.0
# 11             12          9200.0
# 12             13          9550.0
# 13             14          9900.0
# 14             15         10250.0
# 15             16         10600.0
# 16             17         10950.0
# 17             18         12200.0
# 18             19         12600.0
# 19             20         13000.0
# 20             21         13400.0
# 21             22         13800.0
# 22             23         14200.0
# 23             24         14600.0
# 24             25         15000.0
# 25             26         15400.0
# ...

# %%
### New vehicles Old version ###

import matplotlib.pyplot as plt
import pandas as pd

class SalesConsultant:
    def __init__(self, base_salary, commission_per_unit, commission_rate_1, commission_rate_2, commission_rate_3, 
                 sales_level_1, sales_level_2, sales_level_3, sales_level_4, sales_level_5,sales_level_6,sales_level_7, sales_level_8):
        self.base_salary = base_salary
        self.commission_per_unit = commission_per_unit
        self.commission_rate_1 = commission_rate_1
        self.commission_rate_2 = commission_rate_2
        self.commission_rate_3 = commission_rate_3
        self.sales_level_1 = sales_level_1
        self.sales_level_2 = sales_level_2
        self.sales_level_3 = sales_level_3
        self.sales_level_4 = sales_level_4
        self.sales_level_5 = sales_level_5
        self.sales_level_6 = sales_level_6
        self.sales_level_7 = sales_level_7
        self.sales_level_8 = sales_level_8
        self.total_earnings = 0

    def calculate_commission(self, sales, vehicle_sales):
        max_value = self.commission_per_unit
    
        if vehicle_sales >= self.sales_level_8:
            self.total_earnings = self.base_salary * sales + self.commission_rate_1 + 6 * self.commission_rate_2 + self.commission_rate_3 * (vehicle_sales-self.sales_level_8+1) +vehicle_sales * (max_value + Paint_Fabric + Tinted_Windows)
        elif vehicle_sales >= self.sales_level_7:
            self.total_earnings = self.base_salary * sales + self.commission_rate_1 + 6 * self.commission_rate_2 + vehicle_sales * (max_value+ Paint_Fabric + Tinted_Windows)
        elif vehicle_sales >= self.sales_level_6:
            self.total_earnings = self.base_salary * sales + self.commission_rate_1 + 5 * self.commission_rate_2 + vehicle_sales * (max_value+ Paint_Fabric + Tinted_Windows)
        elif vehicle_sales >= self.sales_level_5:
            self.total_earnings = self.base_salary * sales + self.commission_rate_1 + 4 * self.commission_rate_2 + vehicle_sales * (max_value+ Paint_Fabric + Tinted_Windows)
        elif vehicle_sales >= self.sales_level_4:
            self.total_earnings = self.base_salary * sales + self.commission_rate_1 + 3 * self.commission_rate_2 + vehicle_sales * (max_value+ Paint_Fabric + Tinted_Windows)
        elif vehicle_sales >= self.sales_level_3:
            self.total_earnings = self.base_salary * sales + self.commission_rate_1 + 2 * self.commission_rate_2 + vehicle_sales * (max_value+ Paint_Fabric + Tinted_Windows)
        elif vehicle_sales >= self.sales_level_2:
            self.total_earnings = self.base_salary * sales + self.commission_rate_1 + self.commission_rate_2 + vehicle_sales * (max_value+ Paint_Fabric + Tinted_Windows)
        elif vehicle_sales >= self.sales_level_1:
            self.total_earnings = self.base_salary * sales + self.commission_rate_1 + vehicle_sales * (max_value+ Paint_Fabric + Tinted_Windows)
        else: 
            self.total_earnings = self.base_salary * sales

    def calculate_total_earnings(self):
        return self.total_earnings

base_salary = 48676.29/12
commission_per_unit = 100  
commission_rate_1 = 500  
commission_rate_2 = 1000 
commission_rate_3 = 200
sales_level_1 = 8  
sales_level_2 = 10  
sales_level_3 = 12  
sales_level_4 = 15 
sales_level_5 = 18 
sales_level_6 = 20 
sales_level_7 = 25
sales_level_8 = 26 
sales = 1
Paint_Fabric = 100
Tinted_Windows = 50


consultant2 = SalesConsultant(base_salary, commission_per_unit, commission_rate_1, commission_rate_2, commission_rate_3, 
                 sales_level_1, sales_level_2, sales_level_3, sales_level_4, sales_level_5,sales_level_6,sales_level_7, sales_level_8)

vehicle_sales_range = range(1, 41)

earnings2 = []
for vehicle_sales in vehicle_sales_range:
    consultant2.calculate_commission(sales, vehicle_sales)
    total_earnings = consultant2.calculate_total_earnings()
    earnings2.append(total_earnings)

plt.figure(figsize=(10, 5))
plt.plot(vehicle_sales_range, earnings2, label='Total Earnings')
plt.xlabel('Vehicle Sales')
plt.ylabel('Total Earnings')
plt.title('Sales Consultant Earnings vs Vehicle Sales')
plt.grid(True)
plt.legend()
plt.show()

data = {'Vehicle Sales': list(vehicle_sales_range), 'Total Earnings': earnings2}
df = pd.DataFrame(data)
print(df)
# Out:
#     Vehicle Sales  Total Earnings
# 0               1       4056.3575
# 1               2       4056.3575
# 2               3       4056.3575
# 3               4       4056.3575
# 4               5       4056.3575
# 5               6       4056.3575
# 6               7       4056.3575
# 7               8       6556.3575
# 8               9       6806.3575
# 9              10       8056.3575
# 10             11       8306.3575
# 11             12       9556.3575
# 12             13       9806.3575
# 13             14      10056.3575
# 14             15      11306.3575
# 15             16      11556.3575
# 16             17      11806.3575
# 17             18      13056.3575
# 18             19      13306.3575
# 19             20      14556.3575
# 20             21      14806.3575
# 21             22      15056.3575
# 22             23      15306.3575
# 23             24      15556.3575
# 24             25      16806.3575
# 25             26      17256.3575
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.figure(figsize=(10, 5))

plt.plot(vehicle_sales_range, earnings1, label='New', color='blue')
plt.plot(vehicle_sales_range, earnings2, label='Old', color='orange')

plt.xlabel('Vehicle Sales')
plt.ylabel('Total Earnings')
plt.title('Sales Consultants Earnings vs Vehicle Sales')
plt.grid(True)
plt.legend()
plt.show()

data = {'Vehicle Sales': list(vehicle_sales_range), 'New': earnings1, 'Old': earnings2}
df = pd.DataFrame(data)
# Adding a column for the difference
df['Difference'] = df['New'] - df['Old']
print(df)
# Out:
#     Vehicle Sales      New         Old  Difference
# 0               1   5000.0   4056.3575    943.6425
# 1               2   5000.0   4056.3575    943.6425
# 2               3   5000.0   4056.3575    943.6425
# 3               4   5000.0   4056.3575    943.6425
# 4               5   5000.0   4056.3575    943.6425
# 5               6   5000.0   4056.3575    943.6425
# 6               7   5000.0   4056.3575    943.6425
# 7               8   7800.0   6556.3575   1243.6425
# 8               9   8150.0   6806.3575   1343.6425
# 9              10   8500.0   8056.3575    443.6425
# 10             11   8850.0   8306.3575    543.6425
# 11             12   9200.0   9556.3575   -356.3575
# 12             13   9550.0   9806.3575   -256.3575
# 13             14   9900.0  10056.3575   -156.3575
# 14             15  10250.0  11306.3575  -1056.3575
# 15             16  10600.0  11556.3575   -956.3575
# 16             17  10950.0  11806.3575   -856.3575
# ...

# %%
###Used vehicles new version###

import matplotlib.pyplot as plt
import pandas as pd

class SalesConsultant:
    def __init__(self, base_salary, commission_per_unit, commission_rate_1, commission_rate_2, sales_level_1, 
                 sales_level_2, sales_level_3, retained_gross_profit,NPS):
        self.base_salary = base_salary
        self.commission_per_unit = commission_per_unit
        self.commission_rate_1 = commission_rate_1
        self.commission_rate_2 = commission_rate_2
        self.sales_level_1 = sales_level_1
        self.sales_level_2 = sales_level_2
        self.sales_level_3 = sales_level_3
        self.NPS = NPS
        self.retained_gross_profit = retained_gross_profit
        self.total_earnings = 0

    def calculate_commission(self, sales, vehicle_sales):
        max_value = max(self.retained_gross_profit * 0.1, self.commission_per_unit)
    
        if vehicle_sales >= self.sales_level_3 and self.NPS > 5:
            self.total_earnings = self.base_salary * sales + vehicle_sales * (max_value + self.commission_rate_1 *2 + commission_rate_2)
        elif vehicle_sales == self.sales_level_3:
            self.total_earnings = self.base_salary * sales + vehicle_sales * (max_value + self.commission_rate_1 *2)
        elif vehicle_sales >= self.sales_level_2 and self.NPS > 5:
            self.total_earnings = self.base_salary * sales + vehicle_sales * (max_value + self.commission_rate_1 *2)
        elif vehicle_sales >= self.sales_level_2:
            self.total_earnings = self.base_salary * sales + vehicle_sales * (max_value + self.commission_rate_1)
        elif vehicle_sales >= self.sales_level_1 and self.NPS > 5:
            self.total_earnings = self.base_salary * sales + vehicle_sales * (max_value + self.commission_rate_1)
        elif vehicle_sales >= self.sales_level_1:
            self.total_earnings = self.base_salary * sales + vehicle_sales * max_value
        else:
            self.total_earnings = self.base_salary * sales

    def calculate_total_earnings(self):
        return self.total_earnings

base_salary = 60000/12
commission_per_unit = 250  
commission_rate_1 = 50  
commission_rate_2 = 50 
sales_level_1 = 4  
sales_level_2 = 16  
sales_level_3 = 20  
retained_gross_profit = 2000  
sales = 1
NPS = 10


consultant1 = SalesConsultant(base_salary, commission_per_unit, commission_rate_1, commission_rate_2,
                             sales_level_1, sales_level_2, sales_level_3, retained_gross_profit, NPS)

vehicle_sales_range = range(1, 31)

earnings1 = []
for vehicle_sales in vehicle_sales_range:
    consultant1.calculate_commission(sales, vehicle_sales)
    total_earnings = consultant1.calculate_total_earnings()
    earnings1.append(total_earnings)

# 绘制图表
plt.figure(figsize=(10, 5))
plt.plot(vehicle_sales_range, earnings1, label='Total Earnings')
plt.xlabel('Vehicle Sales')
plt.ylabel('Total Earnings')
plt.title('Sales Consultant Earnings vs Vehicle Sales')
plt.grid(True)
plt.legend()
plt.show()

data = {'Vehicle Sales': list(vehicle_sales_range), 'Total Earnings': earnings1}
df = pd.DataFrame(data)
print(df)
# Out:
#     Vehicle Sales  Total Earnings
# 0               1          5000.0
# 1               2          5000.0
# 2               3          5000.0
# 3               4          6200.0
# 4               5          6500.0
# 5               6          6800.0
# 6               7          7100.0
# 7               8          7400.0
# 8               9          7700.0
# 9              10          8000.0
# 10             11          8300.0
# 11             12          8600.0
# 12             13          8900.0
# 13             14          9200.0
# 14             15          9500.0
# 15             16         10600.0
# 16             17         10950.0
# 17             18         11300.0
# 18             19         11650.0
# 19             20         13000.0
# 20             21         13400.0
# 21             22         13800.0
# 22             23         14200.0
# 23             24         14600.0
# 24             25         15000.0
# 25             26         15400.0
# ...

# %%
###Used vehicles old version###

import matplotlib.pyplot as plt
import pandas as pd

class SalesConsultant:
    def __init__(self, base_salary, commission_per_unit, commission_rate_1, commission_rate_2, commission_rate_3, 
                 commission_rate_4, sales_level_1, sales_level_2, sales_level_3, sales_level_4, retained_gross_profit):
        self.base_salary = base_salary
        self.commission_per_unit = commission_per_unit
        self.commission_rate_1 = commission_rate_1
        self.commission_rate_2 = commission_rate_2
        self.commission_rate_3 = commission_rate_3
        self.commission_rate_4 = commission_rate_4
        self.sales_level_1 = sales_level_1
        self.sales_level_2 = sales_level_2
        self.sales_level_3 = sales_level_3
        self.sales_level_4 = sales_level_4
        self.retained_gross_profit = retained_gross_profit
        self.total_earnings = 0

    def calculate_commission(self, sales, vehicle_sales):
        max_value = max(self.retained_gross_profit * 0.1, self.commission_per_unit)
    
        if vehicle_sales > self.sales_level_4:
            self.total_earnings = self.base_salary * sales + self.commission_rate_1 + self.commission_rate_2 + self.commission_rate_3 + vehicle_sales * (max_value+self.commission_rate_4)
        elif vehicle_sales == self.sales_level_4:
            self.total_earnings = self.base_salary * sales + self.commission_rate_1 + self.commission_rate_2 + self.commission_rate_3 + vehicle_sales * max_value
        elif vehicle_sales >= self.sales_level_3:
            self.total_earnings = self.base_salary * sales + self.commission_rate_1 + self.commission_rate_2 + vehicle_sales * max_value
        elif vehicle_sales >= self.sales_level_2:
            self.total_earnings = self.base_salary * sales + self.commission_rate_1 + vehicle_sales * max_value
        elif vehicle_sales >= self.sales_level_1:
            self.total_earnings = self.base_salary * sales + vehicle_sales * max_value
        else: 
            self.total_earnings = self.base_salary * sales

    def calculate_total_earnings(self):
        return self.total_earnings

base_salary = 52000/12
commission_per_unit = 250  
commission_rate_1 = 150  
commission_rate_2 = 300 
commission_rate_3 = 1000
commission_rate_4 = 90
sales_level_1 = 4  
sales_level_2 = 8  
sales_level_3 = 12  
sales_level_4 = 16 
retained_gross_profit = 2000  
sales = 1

consultant2 = SalesConsultant(base_salary, commission_per_unit, commission_rate_1, commission_rate_2, commission_rate_3, 
                 commission_rate_4, sales_level_1, sales_level_2, sales_level_3, sales_level_4, retained_gross_profit)

vehicle_sales_range = range(1, 31)

earnings2 = []
for vehicle_sales in vehicle_sales_range:
    consultant2.calculate_commission(sales, vehicle_sales)
    total_earnings = consultant2.calculate_total_earnings()
    earnings2.append(total_earnings)

# 绘制图表
plt.figure(figsize=(10, 5))
plt.plot(vehicle_sales_range, earnings2, label='Total Earnings')
plt.xlabel('Vehicle Sales')
plt.ylabel('Total Earnings')
plt.title('Sales Consultant Earnings vs Vehicle Sales')
plt.grid(True)
plt.legend()
plt.show()

data = {'Vehicle Sales': list(vehicle_sales_range), 'Total Earnings': earnings2}
df = pd.DataFrame(data)
print(df)
# Out:
#     Vehicle Sales  Total Earnings
# 0               1     4333.333333
# 1               2     4333.333333
# 2               3     4333.333333
# 3               4     5333.333333
# 4               5     5583.333333
# 5               6     5833.333333
# 6               7     6083.333333
# 7               8     6483.333333
# 8               9     6733.333333
# 9              10     6983.333333
# 10             11     7233.333333
# 11             12     7783.333333
# 12             13     8033.333333
# 13             14     8283.333333
# 14             15     8533.333333
# 15             16     9783.333333
# 16             17    11563.333333
# 17             18    11903.333333
# 18             19    12243.333333
# 19             20    12583.333333
# 20             21    12923.333333
# 21             22    13263.333333
# 22             23    13603.333333
# 23             24    13943.333333
# 24             25    14283.333333
# 25             26    14623.333333
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Your SalesConsultant class and other code...

# Plotting the earnings
plt.figure(figsize=(10, 5))

plt.plot(vehicle_sales_range, earnings1, label='New', color='blue')
plt.plot(vehicle_sales_range, earnings2, label='Old', color='orange')

plt.xlabel('Vehicle Sales')
plt.ylabel('Total Earnings')
plt.title('Sales Consultants Earnings vs Vehicle Sales')
plt.grid(True)
plt.legend()
plt.show()

# Creating DataFrame
data = {'Vehicle Sales': list(vehicle_sales_range), 'New': earnings1, 'Old': earnings2}
df = pd.DataFrame(data)

# Adding a column for the difference
df['Difference'] = df['New'] - df['Old']

print(df)
# Out:
#     Vehicle Sales      New           Old   Difference
# 0               1   5000.0   4333.333333   666.666667
# 1               2   5000.0   4333.333333   666.666667
# 2               3   5000.0   4333.333333   666.666667
# 3               4   6200.0   5333.333333   866.666667
# 4               5   6500.0   5583.333333   916.666667
# 5               6   6800.0   5833.333333   966.666667
# 6               7   7100.0   6083.333333  1016.666667
# 7               8   7400.0   6483.333333   916.666667
# 8               9   7700.0   6733.333333   966.666667
# 9              10   8000.0   6983.333333  1016.666667
# 10             11   8300.0   7233.333333  1066.666667
# 11             12   8600.0   7783.333333   816.666667
# 12             13   8900.0   8033.333333   866.666667
# 13             14   9200.0   8283.333333   916.666667
# 14             15   9500.0   8533.333333   966.666667
# 15             16  10600.0   9783.333333   816.666667
# ...
